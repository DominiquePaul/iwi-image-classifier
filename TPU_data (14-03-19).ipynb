# %%
import tensorflow.contrib.tensorrt as trt
import tensorflow as tf

# %%
# !pip install tensorflow==1.12.0
# Out:
# Collecting tensorflow==1.12.0
#   Downloading https://files.pythonhosted.org/packages/22/cc/ca70b78087015d21c5f3f93694107f34ebccb3be9624385a911d4b52ecef/tensorflow-1.12.0-cp36-cp36m-manylinux1_x86_64.whl (83.1MB)
#     100% |████████████████████████████████| 83.1MB 512kB/s eta 0:00:01
# Requirement already satisfied: keras-applications>=1.0.6 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (1.0.7)
# Collecting tensorboard<1.13.0,>=1.12.0 (from tensorflow==1.12.0)
#   Downloading https://files.pythonhosted.org/packages/07/53/8d32ce9471c18f8d99028b7cef2e5b39ea8765bd7ef250ca05b490880971/tensorboard-1.12.2-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.1MB 10.4MB/s ta 0:00:01
# Requirement already satisfied: termcolor>=1.1.0 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (1.1.0)
# Requirement already satisfied: gast>=0.2.0 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (0.2.2)
# Requirement already satisfied: absl-py>=0.1.6 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (0.7.0)
# Requirement already satisfied: grpcio>=1.8.6 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (1.16.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (1.0.9)
# Requirement already satisfied: six>=1.10.0 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (1.12.0)
# Requirement already satisfied: astor>=0.6.0 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (0.7.1)
# Requirement already satisfied: numpy>=1.13.3 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (1.16.2)
# Requirement already satisfied: wheel>=0.26 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (0.33.1)
# Requirement already satisfied: protobuf>=3.6.1 in ./yes/lib/python3.6/site-packages (from tensorflow==1.12.0) (3.6.1)
# Requirement already satisfied: h5py in ./yes/lib/python3.6/site-packages (from keras-applications>=1.0.6->tensorflow==1.12.0) (2.9.0)
# Requirement already satisfied: markdown>=2.6.8 in ./yes/lib/python3.6/site-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12.0) (3.0.1)
# Requirement already satisfied: werkzeug>=0.11.10 in ./yes/lib/python3.6/site-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12.0) (0.14.1)
# Requirement already satisfied: setuptools in ./yes/lib/python3.6/site-packages (from protobuf>=3.6.1->tensorflow==1.12.0) (40.8.0)
# Installing collected packages: tensorboard, tensorflow
#   Found existing installation: tensorboard 1.13.1
#     Uninstalling tensorboard-1.13.1:
#       Successfully uninstalled tensorboard-1.13.1
#   Found existing installation: tensorflow 1.13.1
#     Uninstalling tensorflow-1.13.1:
#       Successfully uninstalled tensorflow-1.13.1
# Successfully installed tensorboard-1.12.2 tensorflow-1.12.0

# %%
# normal estimator
model = tf.estimator.Estimator(model_fn=model_fn,
                               params={"learning_rate": 1e-4},
                               model_dir="./model5/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-186f457b60a0> in <module>
#       1 # normal estimator
# ----> 2 model = tf.estimator.Estimator(model_fn=model_fn,
#       3                                params={"learning_rate": 1e-4},
#       4                                model_dir="./model5/")
#
# NameError: name 'tf' is not defined

# %%
"""
sources:
https://www.youtube.com/watch?v=bqeUmLCgsVw
https://github.com/kalaspuffar/tensorflow-data/blob/master/train.py

https://www.youtube.com/watch?v=ot4RWfGTtOg
"""

import tensorflow as tf
import sys

sess = tf.Session()


def parser(record):
    """
    Takes one record from the tfrecord file and parses image and label out
    """
    keys_to_features = {
        "image_raw": tf.FixedLenFeature([], tf.string),
        "label":     tf.FixedLenFeature([], tf.int64)
    }
    # parse one file
    parsed = tf.parse_single_example(record, keys_to_features)
    # extract image and convert it to float format which is required by the network
    image = tf.decode_raw(parsed["image_raw"], tf.uint8)
    image = tf.cast(image, tf.float32)
    image = tf.reshape(image, shape=[299, 299, 3]) # delete this?
    # read out the label
    label = tf.cast(parsed["label"], tf.int32)
    return {'image': image}, label

def input_fn(filenames, params):
    batch_size = params["batch_size"]
    dataset = tf.data.TFRecordDataset(filenames=filenames, num_parallel_reads=32)
    dataset = dataset.apply(tf.data.experimental.shuffle_and_repeat(1024, 1)) # (sliding window, num_epochs)
    #dataset = dataset.apply(tf.data.experimental.map_and_batch(parser, 1024))
    dataset = dataset.map(parser, num_parallel_calls=12)
    #dataset = dataset.batch_and_drop_remainder(batch_size=1024)
    dataset = dataset.apply(tf.contrib.data.batch_and_drop_remainder(batch_size))
    dataset = dataset.prefetch(buffer_size=2)
    return dataset

def train_input_fn(params):
    return input_fn(filenames=["gs://data-imr-unisg/tfrecords/train.tfrecords"], params)

def val_input_fn(params):
    return input_fn(filenames=["gs://data-imr-unisg/tfrecords/test.tfrecords"], params)

def model_fn(features, labels, mode, params):
    num_classes = 2
    net = features["image"]
    net = tf.identity(net, name="input_tensor")
    net = tf.reshape(net, [-1, 299, 299, 3])
    net = tf.identity(net, name="input_tensor_after")
    net = tf.layers.conv2d(inputs=net, name='layer_conv1',
                           filters=32, kernel_size=3,
                           padding='same', activation=tf.nn.relu)
    net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)
    net = tf.layers.conv2d(inputs=net, name='layer_conv2',
                           filters=64, kernel_size=3,
                           padding='same', activation=tf.nn.relu)
    net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)
    net = tf.layers.conv2d(inputs=net, name='layer_conv3',
                           filters=64, kernel_size=3,
                           padding='same', activation=tf.nn.relu)
    net = tf.layers.max_pooling2d(inputs=net, pool_size=2, strides=2)
    net = tf.layers.flatten(net)
    net = tf.layers.dense(inputs=net, name='layer_fc1',
                        units=128, activation=tf.nn.relu)
    net = tf.layers.dropout(net, rate=0.5, noise_shape=None,
                        seed=None, training=(mode == tf.estimator.ModeKeys.TRAIN))
    net = tf.layers.dense(inputs=net, name='layer_fc_2',
                        units=num_classes)

    logits = net

    y_pred = tf.nn.softmax(logits=logits)
    y_pred = tf.identity(y_pred, name="output_pred")
    y_pred_cls = tf.argmax(y_pred, axis=1)
    y_pred_cls = tf.identity(y_pred_cls, name="output_cls")

    if mode == tf.estimator.ModeKeys.PREDICT:
        spec = tf.estimator.EstimatorSpec(mode=mode, predictions=y_pred_cls)
    else:
        cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits)
        loss = tf.reduce_mean(cross_entropy)
        optimizer = tf.train.AdamOptimizer(learning_rate=params["learning_rate"])
        if FLAGS.use_tpu:
            optimizer = tf.contrib.tpu.CrossShardOptimizer(optimizer)
        train_op = optimizer.minimize(
            loss=loss, global_step=tf.train.get_global_step())
        
        metrics = {
                "accuracy": tf.metrics.accuracy(labels, y_pred_cls)
            }
        
        def my_metric_fn(labels_, y_pred_cls_):
            metrics = {
                "accuracy": tf.metrics.accuracy(labels_, y_pred_cls_)
            }

        spec = tf.estimator.EstimatorSpec(
            mode=mode,
            loss=loss,
            train_op=train_op,
            eval_metric_ops=metrics)
        
        if FLAGS.use_tpu:
            spec = tf.contrib.tpu.TPUEstimatorSpec(
                mode=mode,
                loss=loss,
                train_op=train_op,
                eval_metrics=(my_metric_fn, [labels, y_pred_cls])
            )

    return spec

# %%
# tpu estimator for running locally (works)
model = tf.contrib.tpu.TPUEstimator(
    model_fn=model_fn,
    config=tf.contrib.tpu.RunConfig(),
    use_tpu=False,
    params={"learning_rate": 1e-4},
    model_dir="./model5/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-116b83275a85> in <module>
#       1 # tpu estimator for running locally (works)
# ----> 2 model = tf.contrib.tpu.TPUEstimator(
#       3     model_fn=model_fn,
#       4     config=tf.contrib.tpu.RunConfig(),
#       5     use_tpu=False,
#
# NameError: name 'tf' is not defined

# %%
count = 0
while (count < 10):
    model.train(input_fn=train_input_fn, steps=1)
    result = model.evaluate(input_fn=val_input_fn)
    print(result)
    print("Classification accuracy: {0:.2%}".format(result["accuracy"]))
    sys.stdout.flush()
    count = count + 1
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './model5/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc3e9d4efd0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=2, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-2
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 3 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 131.43262.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-07:52:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-3
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-07:54:01
# INFO:tensorflow:Saving dict for global step 3: accuracy = 0.7228682, global_step = 3, loss = 106.549515
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3: ./model5/model.ckpt-3
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.7228682, 'loss': 106.549515, 'global_step': 3}
# Classification accuracy: 72.29%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-3
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 4 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 86.93978.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-07:54:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-4
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-07:55:25
# INFO:tensorflow:Saving dict for global step 4: accuracy = 0.7228682, global_step = 4, loss = 44.9978
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4: ./model5/model.ckpt-4
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.7228682, 'loss': 44.9978, 'global_step': 4}
# Classification accuracy: 72.29%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-4
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 5 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 63.269943.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-07:55:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-5
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-07:56:49
# INFO:tensorflow:Saving dict for global step 5: accuracy = 0.67248064, global_step = 5, loss = 9.300869
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5: ./model5/model.ckpt-5
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.67248064, 'loss': 9.300869, 'global_step': 5}
# Classification accuracy: 67.25%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-5
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 6 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 58.209908.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-07:57:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-6
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-07:58:12
# INFO:tensorflow:Saving dict for global step 6: accuracy = 0.6124031, global_step = 6, loss = 12.195023
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6: ./model5/model.ckpt-6
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.6124031, 'loss': 12.195023, 'global_step': 6}
# Classification accuracy: 61.24%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-6
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 7 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 59.293728.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-07:58:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-7
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-07:59:35
# INFO:tensorflow:Saving dict for global step 7: accuracy = 0.70155036, global_step = 7, loss = 11.070213
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7: ./model5/model.ckpt-7
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.70155036, 'loss': 11.070213, 'global_step': 7}
# Classification accuracy: 70.16%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-7
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 8 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 32.991867.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-07:59:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-8
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-08:00:58
# INFO:tensorflow:Saving dict for global step 8: accuracy = 0.7209302, global_step = 8, loss = 18.015594
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8: ./model5/model.ckpt-8
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.7209302, 'loss': 18.015594, 'global_step': 8}
# Classification accuracy: 72.09%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-8
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 9 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 26.2713.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-08:01:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-9
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-08:02:21
# INFO:tensorflow:Saving dict for global step 9: accuracy = 0.71511626, global_step = 9, loss = 15.481313
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9: ./model5/model.ckpt-9
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.71511626, 'loss': 15.481313, 'global_step': 9}
# Classification accuracy: 71.51%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-9
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 10 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.769482.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-08:02:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-08:03:43
# INFO:tensorflow:Saving dict for global step 10: accuracy = 0.71899223, global_step = 10, loss = 12.945819
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10: ./model5/model.ckpt-10
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.71899223, 'loss': 12.945819, 'global_step': 10}
# Classification accuracy: 71.90%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-10
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 10 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 11 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 14.381745.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-08:04:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-11
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-08:05:07
# INFO:tensorflow:Saving dict for global step 11: accuracy = 0.71511626, global_step = 11, loss = 10.846758
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11: ./model5/model.ckpt-11
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.71511626, 'loss': 10.846758, 'global_step': 11}
# Classification accuracy: 71.51%
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-11
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 11 into ./model5/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 12 into ./model5/model.ckpt.
# INFO:tensorflow:Loss for final step: 20.22448.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running eval on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-15-08:05:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./model5/model.ckpt-12
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-15-08:06:30
# INFO:tensorflow:Saving dict for global step 12: accuracy = 0.6763566, global_step = 12, loss = 9.951813
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12: ./model5/model.ckpt-12
# INFO:tensorflow:evaluation_loop marked as finished
# {'accuracy': 0.6763566, 'loss': 9.951813, 'global_step': 12}
# Classification accuracy: 67.64%

# %%
import tempfile
import subprocess

class FLAGS(object):
  use_tpu=False
  tpu_name="dominique-c-a-paul"
  model_dir = tempfile.mkdtemp("model5") # Use a local temporary path for the `model_dir`
  iterations = 50 # Number of training steps to run on the Cloud TPU before returning control.
  num_shards = 8  # A single Cloud TPU has 8 shards.

if FLAGS.use_tpu:
    my_project_name = subprocess.check_output(['gcloud','config','get-value','project'])
    my_zone = subprocess.check_output(['gcloud','config','get-value','compute/zone'])
    tpu_cluster_resolver = tf.contrib.cluster_resolver.TPUClusterResolver(
            FLAGS.tpu_name,
            zone="us-central1-f",
            project="imr-unisg")
    master = tpu_cluster_resolver.get_master()
else:
    master = ''

my_tpu_run_config = tf.contrib.tpu.RunConfig(
    master=master,
    evaluation_master=master,
    model_dir=FLAGS.model_dir,
    session_config=tf.ConfigProto(
        allow_soft_placement=True, log_device_placement=True),
    tpu_config=tf.contrib.tpu.TPUConfig(FLAGS.iterations,
                                        FLAGS.num_shards),
)

# %%
#!pip install --upgrade google-api-python-client --force-reinstall
#!pip install --upgrade oauth2client --force-reinstall

# %%
# create a TPU estimator
tpu_estimator = tf.contrib.tpu.TPUEstimator(
    model_fn=model_fn,
    config = my_tpu_run_config,
    use_tpu=FLAGS.use_tpu,
    params={"learning_rate": 1e-4},
    train_batch_size=1024
    #model_dir="./model5/"
)

if False:
    # create an estimator for local running on CPU
    cpu_estimator = tf.contrib.tpu.TPUEstimator(
        model_fn=model_fn,
        config=tf.contrib.tpu.RunConfig(),
        use_tpu=False,
        params={"learning_rate": 1e-4}

        #model_dir="./model5/"
    )
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmphp7rcxqtmodel5', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# log_device_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0bda5e4e10>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=50, num_shards=8, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.

# %%
tpu_estimator.train(input_fn=train_input_fn, max_steps=2)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running train on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmphp7rcxqtmodel5/model.ckpt.

# %%
tpu_estimator.train(input_fn=train_input_fn, max_steps=2)

# %%
count = 0
tf.while_loop(count < 10):
    tpu_estimator.train(input_fn=train_input_fn, steps=1)
    result = tpu_estimator.evaluate(input_fn=val_input_fn)
    print(result)
    print("Classification accuracy: {0:.2%}".format(result["accuracy"]))
    sys.stdout.flush()
    count = count + 1
# Out:
#   File "<ipython-input-114-6620af6494b0>", line 2
#     tf.while_loop(count < 10):
#                               ^
# SyntaxError: invalid syntax

# %%
#### High school kid tutorial 
tpu_cluster_resolver = tf.contrib.cluster_resolver.TPUClusterResolver(
      FLAGS.tpu_name,
      zone=FLAGS.tpu_zone,
      project=FLAGS.gcp_project)
config = tf.contrib.tpu.RunConfig(
      cluster=tpu_cluster_resolver,
      model_dir=FLAGS.model_dir,
      tpu_config=tf.contrib.tpu.TPUConfig(
          num_shards=FLAGS.num_shards,
          iterations_per_loop=FLAGS.iterations_per_loop))

# %%
# !pip install tensorflow=1.12.0
# Out:
# Invalid requirement: 'tensorflow=1.12.0'
# = is not a valid operator. Did you mean == ?
